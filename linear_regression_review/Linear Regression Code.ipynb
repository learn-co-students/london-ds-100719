# %%
# Linear Regression Diagnostics 

import statsmodels.api as sm
import pandas as pd

# %%
iris_dataset = pd.read_csv("iris.csv")

# %%
iris_dataset

target = iris_dataset['Sepal.Length']
predictors = iris_dataset.drop(['Sepal.Length'], axis = 1)

# %%
target
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
# 5      5.4
# 6      4.6
# 7      5.0
# 8      4.4
# 9      4.9
# 10     5.4
# 11     4.8
# 12     4.8
# 13     4.3
# 14     5.8
# 15     5.7
# 16     5.4
# 17     5.1
# 18     5.7
# 19     5.1
# 20     5.4
# 21     5.1
# 22     4.6
# 23     5.1
# 24     4.8
# 25     5.0
# 26     5.0
# 27     5.2
# 28     5.2
# 29     4.7
#       ...
# 120    6.9
# 121    5.6
# 122    7.7
# 123    6.3
# 124    6.7
# 125    7.2
# 126    6.2
# 127    6.1
# 128    6.4
# 129    7.2
# 130    7.4
# 131    7.9
# 132    6.4
# 133    6.3
# 134    6.1
# 135    7.7
# 136    6.3
# 137    6.4
# 138    6.0
# 139    6.9
# 140    6.7
# 141    6.9
# 142    5.8
# 143    6.8
# 144    6.7
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: Sepal.Length, Length: 150, dtype: float64

# %%
predictors

predictors_less = iris_dataset['Petal.Width']

# %%
predictors = pd.get_dummies(predictors)

# %%
predictors
# Out:
#      Unnamed: 0  Sepal.Width  Petal.Length  Petal.Width  Species_setosa  \
# 0             1          3.5           1.4          0.2               1
# 1             2          3.0           1.4          0.2               1
# 2             3          3.2           1.3          0.2               1
# 3             4          3.1           1.5          0.2               1
# 4             5          3.6           1.4          0.2               1
# 5             6          3.9           1.7          0.4               1
# 6             7          3.4           1.4          0.3               1
# 7             8          3.4           1.5          0.2               1
# 8             9          2.9           1.4          0.2               1
# 9            10          3.1           1.5          0.1               1
# 10           11          3.7           1.5          0.2               1
# 11           12          3.4           1.6          0.2               1
# ...

# %%
model = sm.OLS(target, predictors)
results = model.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:           Sepal.Length   R-squared:                       0.867
# Model:                            OLS   Adj. R-squared:                  0.862
# Method:                 Least Squares   F-statistic:                     155.8
# Date:                Mon, 18 Nov 2019   Prob (F-statistic):           3.86e-60
# Time:                        15:26:55   Log-Likelihood:                -32.558
# No. Observations:                 150   AIC:                             79.12
# Df Residuals:                     143   BIC:                             100.2
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# ...

# %%
model_less = sm.OLS(target, predictors_less)
results_less = model_less.fit()
results_less.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:           Sepal.Length   R-squared (uncentered):                   0.806
# Model:                            OLS   Adj. R-squared (uncentered):              0.805
# Method:                 Least Squares   F-statistic:                              618.4
# Date:                Mon, 18 Nov 2019   Prob (F-statistic):                    6.72e-55
# Time:                        15:26:55   Log-Likelihood:                         -356.18
# No. Observations:                 150   AIC:                                      714.4
# Df Residuals:                     149   BIC:                                      717.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# ...
