# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
import seaborn as sns

# %%
data = pd.read_csv('kc_house_data.csv')
data.head()
# Out:
#            id        date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  10/13/2014  221900.0         3       1.00         1180
# 1  6414100192   12/9/2014  538000.0         3       2.25         2570
# 2  5631500400   2/25/2015  180000.0         2       1.00          770
# 3  2487200875   12/9/2014  604000.0         4       3.00         1960
# 4  1954400510   2/18/2015  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view     ...      grade  sqft_above  \
# 0      5650     1.0         NaN   0.0     ...          7        1180
# 1      7242     2.0         0.0   0.0     ...          7        2170
# 2     10000     1.0         0.0   0.0     ...          6         770
# 3      5000     1.0         0.0   0.0     ...          7        1050
# 4      8080     1.0         0.0   0.0     ...          8        1680
#
#    sqft_basement yr_built  yr_renovated  zipcode      lat     long  \
# 0            0.0     1955           0.0    98178  47.5112 -122.257
# 1          400.0     1951        1991.0    98125  47.7210 -122.319
# 2            0.0     1933           NaN    98028  47.7379 -122.233
# 3          910.0     1965           0.0    98136  47.5208 -122.393
# 4            0.0     1987           0.0    98074  47.6168 -122.045
#
#    sqft_living15  sqft_lot15
# 0           1340        5650
# 1           1690        7639
# 2           2720        8062
# 3           1360        5000
# 4           1800        7503
#
# [5 rows x 21 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21597 entries, 0 to 21596
# Data columns (total 21 columns):
# id               21597 non-null int64
# date             21597 non-null object
# price            21597 non-null float64
# bedrooms         21597 non-null int64
# bathrooms        21597 non-null float64
# sqft_living      21597 non-null int64
# sqft_lot         21597 non-null int64
# floors           21597 non-null float64
# waterfront       19221 non-null float64
# view             21534 non-null float64
# condition        21597 non-null int64
# grade            21597 non-null int64
# sqft_above       21597 non-null int64
# sqft_basement    21597 non-null object
# yr_built         21597 non-null int64
# yr_renovated     17755 non-null float64
# zipcode          21597 non-null int64
# lat              21597 non-null float64
# long             21597 non-null float64
# sqft_living15    21597 non-null int64
# sqft_lot15       21597 non-null int64
# dtypes: float64(8), int64(11), object(2)
# memory usage: 3.5+ MB

# %%
data.shape
# Out:
# (21597, 21)

# %%
data.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.159700e+04  2.159700e+04  21597.000000  21597.000000  21597.000000
# mean   4.580474e+09  5.402966e+05      3.373200      2.115826   2080.321850
# std    2.876736e+09  3.673681e+05      0.926299      0.768984    918.106125
# min    1.000102e+06  7.800000e+04      1.000000      0.500000    370.000000
# 25%    2.123049e+09  3.220000e+05      3.000000      1.750000   1430.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.159700e+04  21597.000000  19221.000000  21534.000000  21597.000000
# mean   1.509941e+04      1.494096      0.007596      0.233863      3.409825
# std    4.141264e+04      0.539683      0.086825      0.765686      0.650546
# min    5.200000e+02      1.000000      0.000000      0.000000      1.000000
# 25%    5.040000e+03      1.000000      0.000000      0.000000      3.000000
# 50%    7.618000e+03      1.500000      0.000000      0.000000      3.000000
# 75%    1.068500e+04      2.000000      0.000000      0.000000      4.000000
# max    1.651359e+06      3.500000      1.000000      4.000000      5.000000
#
#               grade    sqft_above      yr_built  yr_renovated       zipcode  \
# count  21597.000000  21597.000000  21597.000000  17755.000000  21597.000000
# mean       7.657915   1788.596842   1970.999676     83.636778  98077.951845
# std        1.173200    827.759761     29.375234    399.946414     53.513072
# min        3.000000    370.000000   1900.000000      0.000000  98001.000000
# 25%        7.000000   1190.000000   1951.000000      0.000000  98033.000000
# 50%        7.000000   1560.000000   1975.000000      0.000000  98065.000000
# 75%        8.000000   2210.000000   1997.000000      0.000000  98118.000000
# max       13.000000   9410.000000   2015.000000   2015.000000  98199.000000
#
#                 lat          long  sqft_living15     sqft_lot15
# count  21597.000000  21597.000000   21597.000000   21597.000000
# mean      47.560093   -122.213982    1986.620318   12758.283512
# std        0.138552      0.140724     685.230472   27274.441950
# min       47.155900   -122.519000     399.000000     651.000000
# 25%       47.471100   -122.328000    1490.000000    5100.000000
# 50%       47.571800   -122.231000    1840.000000    7620.000000
# 75%       47.678000   -122.125000    2360.000000   10083.000000
# max       47.777600   -121.315000    6210.000000  871200.000000

# %%
data.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
data.any().any()
# Out:
# True

# %%
# tells me how much in total
data.isna().sum()
# Out:
# id                  0
# date                0
# price               0
# bedrooms            0
# bathrooms           0
# sqft_living         0
# sqft_lot            0
# floors              0
# waterfront       2376
# view               63
# condition           0
# grade               0
# sqft_above          0
# sqft_basement       0
# yr_built            0
# yr_renovated     3842
# zipcode             0
# lat                 0
# long                0
# sqft_living15       0
# sqft_lot15          0
# dtype: int64

# %%
#drop all null values
data.dropna(inplace=True)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15762 entries, 1 to 21596
# Data columns (total 21 columns):
# id               15762 non-null int64
# date             15762 non-null object
# price            15762 non-null float64
# bedrooms         15762 non-null int64
# bathrooms        15762 non-null float64
# sqft_living      15762 non-null int64
# sqft_lot         15762 non-null int64
# floors           15762 non-null float64
# waterfront       15762 non-null float64
# view             15762 non-null float64
# condition        15762 non-null int64
# grade            15762 non-null int64
# sqft_above       15762 non-null int64
# sqft_basement    15762 non-null object
# yr_built         15762 non-null int64
# yr_renovated     15762 non-null float64
# zipcode          15762 non-null int64
# lat              15762 non-null float64
# long             15762 non-null float64
# sqft_living15    15762 non-null int64
# sqft_lot15       15762 non-null int64
# dtypes: float64(8), int64(11), object(2)
# memory usage: 2.6+ MB

# %%
data.shape
# Out:
# (15762, 21)

# %%
data['waterfront'].unique()
# Out:
# array([0., 1.])

# %%
data['yr_renovated'].unique()
# Out:
# array([1991.,    0., 2002., 2010., 1992., 2013., 1994., 1978., 2005.,
#        2003., 1984., 1954., 2014., 2011., 1983., 1990., 1988., 1977.,
#        1981., 1995., 2000., 1999., 1998., 1970., 1989., 2004., 1986.,
#        2007., 1987., 2006., 1985., 2001., 1980., 1971., 1945., 1979.,
#        1997., 1950., 1969., 1948., 2009., 2015., 2008., 2012., 1968.,
#        1963., 1951., 1962., 1953., 1993., 1955., 1996., 1982., 1956.,
#        1940., 1976., 1946., 1975., 1964., 1973., 1957., 1959., 1960.,
#        1965., 1967., 1934., 1972., 1944., 1958., 1974.])

# %%
#write code for value count see where there are errors

for col in list(data.columns):
    print ("the value count in {} is: /n".format(col), data[col].value_counts())
# Out:
# the value count in id is: /n 6632900574    2
# 9353300600    2
# 5101402435    2
# 722039087     2
# 1523049207    2
# 9407110710    2
# 3271300955    2
# 9834200885    2
# 1139600270    2
# 6300000226    2
# 5282200015    2
# 4154300296    2
# 7657000540    2
# 1219000473    2
# 7853400250    2
# 1231000510    2
# 8682262400    2
# 5083000375    2
# 2422049104    2
# 3333002450    2
# 3432501415    2
# 1036400200    2
# 5536100020    2
# 3528000040    2
# 8121100395    2
# 7856400300    2
# 9828200460    2
# 2787460720    2
# 1721801010    2
# 3558900590    2
#              ..
# 254000445     1
# 5104510270    1
# 2207100255    1
# 9477920120    1
# 5606000120    1
# 2159900020    1
# 1376800115    1
# 3793700210    1
# 9460000110    1
# 5095400760    1
# 7203140360    1
# 2326300010    1
# 1665400165    1
# 4137010530    1
# 7905400160    1
# 984200540     1
# 5418500650    1
# 8682210650    1
# 6145600855    1
# 4388000120    1
# 7277100395    1
# 3291800670    1
# 2767603026    1
# 9557300560    1
# 1460000080    1
# 7211400525    1
# 1531000140    1
# 510002506     1
# 2391602500    1
# 808300550     1
# Name: id, Length: 15676, dtype: int64
# the value count in date is: /n 6/25/2014     103
# 6/23/2014     102
# 4/28/2015      93
# 7/14/2014      93
# 7/8/2014       93
# 10/28/2014     92
# 5/20/2014      89
# 8/20/2014      89
# 4/27/2015      89
# 7/9/2014       88
# 4/21/2015      88
# 4/22/2015      88
# 5/27/2014      87
# 6/26/2014      87
# 4/14/2015      86
# 7/16/2014      86
# 4/8/2015       85
# 8/26/2014      85
# 6/24/2014      85
# 3/25/2015      84
# 7/1/2014       83
# 4/29/2015      83
# 4/23/2015      82
# 7/29/2014      82
# 4/24/2015      82
# 3/26/2015      82
# 8/25/2014      81
# 7/25/2014      81
# 5/28/2014      81
# 8/5/2014       81
#              ...
# 8/9/2014        2
# 7/26/2014       2
# 10/12/2014      2
# 2/21/2015       2
# 10/5/2014       2
# 12/21/2014      2
# 12/27/2014      2
# 3/15/2015       2
# 11/23/2014      2
# 5/18/2014       2
# 7/6/2014        1
# 11/30/2014      1
# 8/3/2014        1
# 2/1/2015        1
# 11/28/2014      1
# 11/15/2014      1
# 5/27/2015       1
# 7/13/2014       1
# 11/2/2014       1
# 5/11/2014       1
# 7/27/2014       1
# 5/10/2015       1
# 1/17/2015       1
# 5/24/2015       1
# 7/4/2014        1
# 8/31/2014       1
# 5/15/2015       1
# 1/10/2015       1
# 5/17/2014       1
# 3/8/2015        1
# Name: date, Length: 369, dtype: int64
# the value count in price is: /n 350000.0     129
# 450000.0     120
# 500000.0     115
# 550000.0     113
# 425000.0     111
# 525000.0     104
# 400000.0     100
# 325000.0      98
# 375000.0      97
# 300000.0      96
# 475000.0      96
# 250000.0      95
# 330000.0      88
# 275000.0      88
# 320000.0      85
# 440000.0      85
# 280000.0      83
# 315000.0      82
# 415000.0      81
# 390000.0      78
# 435000.0      77
# 380000.0      76
# 600000.0      74
# 310000.0      73
# 245000.0      73
# 650000.0      73
# 340000.0      73
# 305000.0      73
# 360000.0      72
# 420000.0      71
#             ...
# 300500.0       1
# 857500.0       1
# 730100.0       1
# 533500.0       1
# 365070.0       1
# 438800.0       1
# 384500.0       1
# 274975.0       1
# 6890000.0      1
# 868000.0       1
# 615500.0       1
# 828500.0       1
# 291375.0       1
# 381500.0       1
# 503500.0       1
# 389700.0       1
# 582800.0       1
# 397900.0       1
# 447055.0       1
# 182568.0       1
# 106000.0       1
# 406100.0       1
# 713900.0       1
# 306888.0       1
# 419995.0       1
# 275053.0       1
# 763101.0       1
# 438900.0       1
# 959750.0       1
# 311300.0       1
# Name: price, Length: 3034, dtype: int64
# the value count in bedrooms is: /n 3     7120
# 4     5079
# 2     2003
# 5     1183
# 6      192
# 1      141
# 7       23
# 8       10
# 9        6
# 10       3
# 11       1
# 33       1
# Name: bedrooms, dtype: int64
# the value count in bathrooms is: /n 2.50    4004
# 1.00    2761
# 1.75    2226
# 2.25    1487
# 2.00    1395
# 1.50    1060
# 2.75     853
# 3.00     543
# 3.50     543
# 3.25     428
# 3.75     104
# 4.00     100
# 4.50      75
# 4.25      62
# 0.75      50
# 4.75      17
# 5.00      14
# 5.25      11
# 5.50       8
# 1.25       6
# 6.00       5
# 0.50       3
# 8.00       2
# 5.75       2
# 7.75       1
# 7.50       1
# 6.75       1
# Name: bathrooms, dtype: int64
# the value count in sqft_living is: /n 1820    102
# 1440    100
# 1400     97
# 1300     95
# 1320     94
# 1720     91
# 1540     91
# 1510     89
# 1800     89
# 1830     88
# 2040     88
# 1480     88
# 1250     87
# 2100     87
# 1740     87
# 1650     87
# 1680     86
# 1660     86
# 1460     86
# 1700     86
# 1900     85
# 1780     85
# 1560     84
# 1280     83
# 1370     83
# 1010     83
# 1790     83
# 1610     82
# 1340     82
# 1980     82
#        ...
# 2594      1
# 1946      1
# 6040      1
# 3931      1
# 1594      1
# 4580      1
# 5520      1
# 2495      1
# 1458      1
# 5584      1
# 390       1
# 5600      1
# 3555      1
# 1522      1
# 2415      1
# 3595      1
# 5720      1
# 3915      1
# 1626      1
# 1658      1
# 5760      1
# 2311      1
# 5840      1
# 2223      1
# 1778      1
# 1794      1
# 1802      1
# 1834      1
# 5960      1
# 2531      1
# Name: sqft_living, Length: 912, dtype: int64
# the value count in sqft_lot is: /n 5000      277
# 6000      204
# 4000      177
# 7200      151
# 4800       89
# 4500       88
# 8400       82
# 7500       80
# 9600       79
# 3600       75
# 9000       69
# 3000       63
# 8000       63
# 5100       59
# 8100       53
# 7000       52
# 5500       51
# 7800       50
# 7350       50
# 4080       49
# 7700       48
# 5750       46
# 6250       43
# 5200       42
# 7560       42
# 5400       41
# 4400       40
# 6600       37
# 6500       36
# 4200       34
#          ...
# 7928        1
# 3834        1
# 1787        1
# 11595       1
# 1795        1
# 252648      1
# 77574       1
# 1763        1
# 5857        1
# 9911        1
# 7880        1
# 7864        1
# 36183       1
# 3770        1
# 1760        1
# 7872        1
# 5825        1
# 14021       1
# 9927        1
# 18123       1
# 11603       1
# 9935        1
# 3794        1
# 184140      1
# 6455        1
# 7509        1
# 4232        1
# 1755        1
# 11998       1
# 2999        1
# Name: sqft_lot, Length: 7927, dtype: int64
# the value count in floors is: /n 1.0    7777
# 2.0    6049
# 1.5    1374
# 3.0     439
# 2.5     117
# 3.5       6
# Name: floors, dtype: int64
# the value count in waterfront is: /n 0.0    15642
# 1.0      120
# Name: waterfront, dtype: int64
# the value count in view is: /n 0.0    14241
# 2.0      688
# 3.0      348
# 1.0      245
# 4.0      240
# Name: view, dtype: int64
# the value count in condition is: /n 3    10221
# 4     4137
# 5     1254
# 2      131
# 1       19
# Name: condition, dtype: int64
# the value count in grade is: /n 7     6539
# 8     4438
# 9     1920
# 6     1482
# 10     832
# 11     290
# 5      167
# 12      66
# 4       16
# 13      11
# 3        1
# Name: grade, dtype: int64
# the value count in sqft_above is: /n 1300    152
# 1200    144
# 1010    143
# 1220    137
# 1060    134
# 1180    131
# 1140    131
# 1320    130
# 1250    129
# 1080    129
# 1340    126
# 1400    123
# 1150    122
# 1290    119
# 1440    118
# 1210    117
# 1100    115
# 1040    115
# 1280    114
# 1240    112
# 1390    111
# 1370    110
# 1260    109
# 1120    108
# 960     106
# 1540    106
# 1090    106
# 1460    105
# 1270    105
# 1430    104
#        ...
# 2594      1
# 6720      1
# 1453      1
# 2658      1
# 1834      1
# 3859      1
# 1802      1
# 1794      1
# 5160      1
# 4580      1
# 5240      1
# 2495      1
# 5320      1
# 5400      1
# 1322      1
# 390       1
# 5440      1
# 8570      1
# 2415      1
# 5584      1
# 4420      1
# 3555      1
# 3595      1
# 2311      1
# 1578      1
# 1658      1
# 5760      1
# 2223      1
# 1778      1
# 1811      1
# Name: sqft_above, Length: 835, dtype: int64
# the value count in sqft_basement is: /n 0.0       9362
# ?          333
# 600.0      155
# 500.0      151
# 700.0      148
# 400.0      144
# 800.0      139
# 900.0      101
# 1000.0      99
# 300.0       98
# 750.0       82
# 530.0       81
# 450.0       76
# 200.0       74
# 480.0       71
# 580.0       71
# 720.0       68
# 620.0       65
# 420.0       63
# 840.0       61
# 680.0       60
# 860.0       59
# 360.0       59
# 440.0       56
# 780.0       56
# 650.0       55
# 1200.0      55
# 520.0       54
# 1100.0      54
# 550.0       54
#           ...
# 2120.0       1
# 435.0        1
# 417.0        1
# 3500.0       1
# 2850.0       1
# 243.0        1
# 516.0        1
# 1284.0       1
# 2080.0       1
# 1281.0       1
# 2720.0       1
# 935.0        1
# 862.0        1
# 248.0        1
# 518.0        1
# 1913.0       1
# 1024.0       1
# 172.0        1
# 2810.0       1
# 1840.0       1
# 4400      1
# 2323      1
# 1708      1
# 1716      1
# 1884      1
# 6110      1
# 2049      1
# Name: sqft_living15, Length: 694, dtype: int64
# the value count in sqft_lot15 is: /n 5000     313
# 4000     262
# 6000     201
# 7200     153
# 7500     102
# 4800      99
# 4500      89
# 3600      86
# 5100      84
# 8400      78
# 4080      78
# 8000      76
# 9600      73
# 7800      66
# 7700      65
# 9000      65
# 8100      65
# 5500      61
# 5400      53
# 5200      51
# 5750      50
# 7350      48
# 6600      47
# 7560      43
# 4200      43
# 4400      42
# 5250      40
# 6250      38
# 9750      38
# 3000      38
#         ...
# 3450       1
# 9314       1
# 15457      1
# 9607       1
# 5212       1
# 19850      1
# 13709      1
# 8348       1
# 7568       1
# 9306       1
# 9623       1
# 1205       1
# 7269       1
# 1126       1
# 9724       1
# 5244       1
# 1363       1
# 15700      1
# 44374      1
# 7512       1
# 5236       1
# 7520       1
# 3175       1
# 3426       1
# 5228       1
# 15716      1
# 19134      1
# 11622      1
# 24700      1
# 6147       1
# Name: sqft_lot15, Length: 7126, dtype: int64

# %%
data = data[(data['sqft_basement'] != '?')]

# %%
data.sqft_basement.value_counts().sort_values()
# Out:
# 415.0        1
# 10.0         1
# 207.0        1
# 2490.0       1
# 1135.0       1
# 1852.0       1
# 2580.0       1
# 2250.0       1
# 2050.0       1
# 768.0        1
# 274.0        1
# 2730.0       1
# 602.0        1
# 2190.0       1
# 1798.0       1
# 3480.0       1
# 4130.0       1
# 506.0        1
# 784.0        1
# 1990.0       1
# 1960.0       1
# 2196.0       1
# 861.0        1
# 2090.0       1
# 2310.0       1
# 2300.0       1
# 1248.0       1
# 2130.0       1
# 2350.0       1
# 515.0        1
#           ...
# 520.0       54
# 550.0       54
# 240.0       54
# 1100.0      54
# 1200.0      55
# 650.0       55
# 780.0       56
# 440.0       56
# 360.0       59
# 860.0       59
# 680.0       60
# 840.0       61
# 420.0       63
# 620.0       65
# 720.0       68
# 580.0       71
# 480.0       71
# 200.0       74
# 450.0       76
# 530.0       81
# 750.0       82
# 300.0       98
# 1000.0      99
# 900.0      101
# 800.0      139
# 400.0      144
# 700.0      148
# 500.0      151
# 600.0      155
# 0.0       9362
# Name: sqft_basement, Length: 282, dtype: int64

# %%
data['bedrooms'] = data['bedrooms'].astype('float64')
data['sqft_basement'] = data['sqft_basement'].astype('float64')

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15429 entries, 1 to 21596
# Data columns (total 21 columns):
# id               15429 non-null int64
# date             15429 non-null object
# price            15429 non-null float64
# bedrooms         15429 non-null float64
# bathrooms        15429 non-null float64
# sqft_living      15429 non-null int64
# sqft_lot         15429 non-null int64
# floors           15429 non-null float64
# waterfront       15429 non-null float64
# view             15429 non-null float64
# condition        15429 non-null int64
# grade            15429 non-null int64
# sqft_above       15429 non-null int64
# sqft_basement    15429 non-null float64
# yr_built         15429 non-null int64
# yr_renovated     15429 non-null float64
# zipcode          15429 non-null int64
# lat              15429 non-null float64
# long             15429 non-null float64
# sqft_living15    15429 non-null int64
# sqft_lot15       15429 non-null int64
# dtypes: float64(10), int64(10), object(1)
# memory usage: 2.6+ MB

# %%
# groupbyby()
#  detecting missing data
#import seaborn as sns
#data.groupby('grade')['price'].mean()
#data.groupby(data['zipcode'].mean()
f, ax = plt.subplots(figsize=(8,6))
fig = sns.boxplot(x='grade', y='price', data=data)

# %%
data['year_sold'] = data['date'].map(lambda x: x[-4:])

# %%
data.yr_renovated.unique()
# Out:
# array([1991.,    0., 2002., 2010., 1992., 2013., 1994., 1978., 2005.,
#        2003., 1984., 1954., 2014., 2011., 1983., 1990., 1988., 1977.,
#        1981., 1995., 2000., 1999., 1998., 1970., 1989., 2004., 1986.,
#        2007., 1987., 2006., 1985., 1980., 1971., 1945., 1979., 1997.,
#        1950., 1969., 1948., 2009., 2015., 2008., 2012., 1968., 1963.,
#        1951., 1962., 2001., 1953., 1993., 1955., 1996., 1982., 1956.,
#        1940., 1976., 1975., 1964., 1973., 1957., 1959., 1960., 1965.,
#        1967., 1934., 1972., 1944., 1958., 1974.])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15429 entries, 1 to 21596
# Data columns (total 22 columns):
# id               15429 non-null int64
# date             15429 non-null object
# price            15429 non-null float64
# bedrooms         15429 non-null float64
# bathrooms        15429 non-null float64
# sqft_living      15429 non-null int64
# sqft_lot         15429 non-null int64
# floors           15429 non-null float64
# waterfront       15429 non-null float64
# view             15429 non-null float64
# condition        15429 non-null int64
# grade            15429 non-null int64
# sqft_above       15429 non-null int64
# sqft_basement    15429 non-null float64
# yr_built         15429 non-null int64
# yr_renovated     15429 non-null float64
# zipcode          15429 non-null int64
# lat              15429 non-null float64
# long             15429 non-null float64
# sqft_living15    15429 non-null int64
# sqft_lot15       15429 non-null int64
# year_sold        15429 non-null object
# dtypes: float64(10), int64(10), object(2)
# memory usage: 3.3+ MB

# %%
#convert year sold to integer
data['year_sold'] = data['year_sold'].astype('int64')

# %%
#using lambda function to find the age of the building by taking out yr built from yr sold
data = data.assign(age = lambda x: x['year_sold'] - x['yr_built'])
data.head()
# Out:
#            id       date      price  bedrooms  bathrooms  sqft_living  \
# 1  6414100192  12/9/2014   538000.0       3.0       2.25         2570
# 3  2487200875  12/9/2014   604000.0       4.0       3.00         1960
# 4  1954400510  2/18/2015   510000.0       3.0       2.00         1680
# 5  7237550310  5/12/2014  1230000.0       4.0       4.50         5420
# 8  2414600126  4/15/2015   229500.0       3.0       1.00         1780
#
#    sqft_lot  floors  waterfront  view ...   sqft_basement  yr_built  \
# 1      7242     2.0         0.0   0.0 ...           400.0      1951
# 3      5000     1.0         0.0   0.0 ...           910.0      1965
# 4      8080     1.0         0.0   0.0 ...             0.0      1987
# 5    101930     1.0         0.0   0.0 ...          1530.0      2001
# 8      7470     1.0         0.0   0.0 ...           730.0      1960
#
#    yr_renovated  zipcode      lat     long  sqft_living15  sqft_lot15  \
# 1        1991.0    98125  47.7210 -122.319           1690        7639
# 3           0.0    98136  47.5208 -122.393           1360        5000
# 4           0.0    98074  47.6168 -122.045           1800        7503
# 5           0.0    98053  47.6561 -122.005           4760      101930
# 8           0.0    98146  47.5123 -122.337           1780        8113
#
#    year_sold  age
# 1       2014   63
# 3       2014   49
# 4       2015   28
# 5       2014   13
# 8       2015   55
#
# [5 rows x 23 columns]

# %%
import statsmodels.api as sm

data1 = data.loc[:,['price', 'sqft_living', 'grade', 'yr_renovated', 'age', 'lat', 'long']]
x = data1.drop('price', axis=1)
y = data1['price']
x = sm.add_constant(x)
model_sm = sm.OLS(y,x)
results = model_sm.fit()
r2 = results.rsquared
r2 = r2.round(2)
print('R2 = {}'.format(r2))
est_b = results.params
print(est_b.round(4))
results.summary()
# Out:
# R2 = 0.64
# const          -4.339654e+07
# sqft_living     1.980044e+02
# grade           1.182943e+05
# yr_renovated    3.398550e+01
# age             2.689195e+03
# lat             5.235490e+05
# long           -1.440097e+05
# dtype: float64
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.644
# Model:                            OLS   Adj. R-squared:                  0.644
# Method:                 Least Squares   F-statistic:                     4659.
# Date:                Wed, 23 Oct 2019   Prob (F-statistic):               0.00
# Time:                        13:31:36   Log-Likelihood:            -2.1186e+05
# No. Observations:               15429   AIC:                         4.237e+05
# Df Residuals:                   15422   BIC:                         4.238e+05
# Df Model:                           6
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const         -4.34e+07    1.8e+06    -24.148      0.000   -4.69e+07   -3.99e+07
# sqft_living    198.0044      3.073     64.425      0.000     191.980     204.029
# grade         1.183e+05   2566.152     46.098      0.000    1.13e+05    1.23e+05
# yr_renovated    33.9855      4.686      7.253      0.000      24.801      43.170
# age           2689.1954     77.035     34.909      0.000    2538.197    2840.194
# lat           5.235e+05   1.34e+04     39.074      0.000    4.97e+05     5.5e+05
# long          -1.44e+05   1.42e+04    -10.138      0.000   -1.72e+05   -1.16e+05
# ==============================================================================
# Omnibus:                    14262.614   Durbin-Watson:                   1.981
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1504521.045
# Skew:                           4.095   Prob(JB):                         0.00
# Kurtosis:                      50.678   Cond. No.                     2.29e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.29e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
data2 = data.loc[:,['price', 'sqft_living', 'grade', 'yr_renovated', 'age', 'lat', 'long']]
data2['price'] = np.log(data['price'])
data2.head()
# Out:
#        price  sqft_living  grade  yr_renovated  age      lat     long
# 1  13.195614         2570      7        1991.0   63  47.7210 -122.319
# 3  13.311329         1960      7           0.0   49  47.5208 -122.393
# 4  13.142166         1680      8           0.0   28  47.6168 -122.045
# 5  14.022525         5420     11           0.0   13  47.6561 -122.005
# 8  12.343658         1780      7           0.0   55  47.5123 -122.337

# %%
data3 = data2.loc[:,['price', 'sqft_living','yr_renovated', 'age','lat']]
x = data3.drop('price', axis=1)
y = data3['price']
x = sm.add_constant(x)
model_sm = sm.OLS(y,x)
results = model_sm.fit()
r2 = results.rsquared
r2 = r2.round(2)
print('R2 = {}'.format(r2))
est_b = results.params
print(est_b.round(4))
results.summary()
# Out:
# R2 = 0.67
# const          -60.0057
# sqft_living      0.0004
# yr_renovated     0.0001
# age              0.0013
# lat              1.5173
# dtype: float64
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.667
# Model:                            OLS   Adj. R-squared:                  0.667
# Method:                 Least Squares   F-statistic:                     7717.
# Date:                Wed, 23 Oct 2019   Prob (F-statistic):               0.00
# Time:                        13:31:36   Log-Likelihood:                -3518.7
# No. Observations:               15429   AIC:                             7047.
# Df Residuals:                   15424   BIC:                             7086.
# Df Model:                           4
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const          -60.0057      0.852    -70.429      0.000     -61.676     -58.336
# sqft_living      0.0004   2.85e-06    139.838      0.000       0.000       0.000
# yr_renovated  6.509e-05   6.39e-06     10.180      0.000    5.26e-05    7.76e-05
# age              0.0013   9.23e-05     14.248      0.000       0.001       0.001
# lat              1.5173      0.018     84.569      0.000       1.482       1.552
# ==============================================================================
# Omnibus:                      468.280   Durbin-Watson:                   1.977
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1259.993
# Skew:                          -0.002   Prob(JB):                    2.49e-274
# Kurtosis:                       4.400   Cond. No.                     7.94e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.94e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
data4 = data2.loc[:,['price', 'sqft_living', 'grade','age','lat','long']]

# Setting up the LEARNER
x = data4.drop('price', axis=1)
y = data4['price']


x = sm.add_constant(x)
model_sm = sm.OLS(y,x)
results = model_sm.fit()
r2 = results.rsquared
r2 = r2.round(2)
print('R2 = {}'.format(r2))
est_b = results.params
print(est_b.round(4))
results.summary()
# Out:
# R2 = 0.73
# const         -54.4730
# sqft_living     0.0002
# grade           0.1975
# age             0.0035
# lat             1.3254
# long           -0.0192
# dtype: float64
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.734
# Model:                            OLS   Adj. R-squared:                  0.734
# Method:                 Least Squares   F-statistic:                     8515.
# Date:                Wed, 23 Oct 2019   Prob (F-statistic):               0.00
# Time:                        13:31:36   Log-Likelihood:                -1779.5
# No. Observations:               15429   AIC:                             3571.
# Df Residuals:                   15423   BIC:                             3617.
# Df Model:                           5
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const         -54.4730      2.194    -24.831      0.000     -58.773     -50.173
# sqft_living     0.0002   3.75e-06     61.557      0.000       0.000       0.000
# grade           0.1975      0.003     63.119      0.000       0.191       0.204
# age             0.0035   9.14e-05     37.807      0.000       0.003       0.004
# lat             1.3254      0.016     81.044      0.000       1.293       1.357
# long           -0.0192      0.017     -1.105      0.269      -0.053       0.015
# ==============================================================================
# Omnibus:                      344.507   Durbin-Watson:                   1.980
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              758.210
# Skew:                           0.070   Prob(JB):                    2.27e-165
# Kurtosis:                       4.077   Cond. No.                     2.29e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.29e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
data.head(5)
# Out:
#            id       date      price  bedrooms  bathrooms  sqft_living  \
# 1  6414100192  12/9/2014   538000.0       3.0       2.25         2570
# 3  2487200875  12/9/2014   604000.0       4.0       3.00         1960
# 4  1954400510  2/18/2015   510000.0       3.0       2.00         1680
# 5  7237550310  5/12/2014  1230000.0       4.0       4.50         5420
# 8  2414600126  4/15/2015   229500.0       3.0       1.00         1780
#
#    sqft_lot  floors  waterfront  view ...   sqft_basement  yr_built  \
# 1      7242     2.0         0.0   0.0 ...           400.0      1951
# 3      5000     1.0         0.0   0.0 ...           910.0      1965
# 4      8080     1.0         0.0   0.0 ...             0.0      1987
# 5    101930     1.0         0.0   0.0 ...          1530.0      2001
# 8      7470     1.0         0.0   0.0 ...           730.0      1960
#
#    yr_renovated  zipcode      lat     long  sqft_living15  sqft_lot15  \
# 1        1991.0    98125  47.7210 -122.319           1690        7639
# 3           0.0    98136  47.5208 -122.393           1360        5000
# 4           0.0    98074  47.6168 -122.045           1800        7503
# 5           0.0    98053  47.6561 -122.005           4760      101930
# 8           0.0    98146  47.5123 -122.337           1780        8113
#
#    year_sold  age
# 1       2014   63
# 3       2014   49
# 4       2015   28
# 5       2014   13
# 8       2015   55
#
# [5 rows x 23 columns]
